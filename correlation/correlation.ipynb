# %%
import pandas as pd
import numpy as np
df =pd.read_csv("Merged_Data.csv")
df = df.drop(['Unnamed: 0'],axis =1)

# %%
df
# Out:
#                                                    NTA  Count  Male_Prct  \
# 0                              Allerton-Pelham Gardens  14091      0.477
# 1           Annadale-Huguenot-Prince's Bay-Eltingville   9225      0.505
# 2                                        Arden Heights   6532      0.495
# 3                                              Astoria  34609      0.500
# 4                                           Auburndale   5528      0.480
# 5                                         Baisley Park  22271      0.462
# 6                                           Bath Beach  11944      0.509
# 7                                            Bay Ridge  35817      0.476
# 8                                Bayside-Bayside Hills  13058      0.480
# 9                                              Bedford  53692      0.483
# 10                          Bedford Park-Fordham North  44154      0.485
# 11                                           Bellerose   7221      0.485
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure = sns.jointplot(x="Ins_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of insurance buyers and crime count")
plt.show()
figure = figure.savefig("Ins_Prct.png", format ='png', dpi =1000)
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="Bl_Pvt_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of population below the poverty line and crime count")
figure = figure.savefig("Bl_Pvt_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="M_Mrg_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of men married and crime count")
figure = figure.savefig("M_Mrg_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="F_Mrg_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of women married and crime count")
figure = figure.savefig("F_Mrg_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="Bf_Hs_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of population without high school diploma and crime count")
figure = figure.savefig("Bf_Hs_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure = sns.jointplot(x="Af_Hs_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of population with high school diploma and crime count")

figure = figure.savefig("Af_Hs_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure = sns.jointplot(x="Vtr_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of veteran and crime count")
figure = figure.savefig("Vtr_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="Dis_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
#plt.title("Correlation between the percentage of the disabled and crime count")
figure = figure.savefig("Dis_Prct.png", format ='png', dpi =1000)
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
import seaborn as sns
import matplotlib.pyplot as plt
figure =sns.jointplot(x="Citi_Prct", y="Count", data=df, kind ='reg')
#ax.set(xlabel='Ins_Prct', ylabel='Count', title ="The correlation between the percentage of insurance buyers and crime count")
#sns.plt.title('YOUR TITLE HERE')
figure = figure.savefig("Citi_Prct.png", format ='png', dpi =1000)
#plt.title("Correlation between the percentage of citizen and crime count")
plt.show()
# Out:
# C:\Users\sherryyang\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
